# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
wind_data="/home/flyranch/field_data_and_analysis_scripts/2021lab/wind_data_textfiles/2021_10_14_test.txt"
pd_wind=pd.read_csv(wind_data, delimiter=' ')
pd_wind
# Out:
#        1634248020.483796   255.3784  0.401781
# 0           1.634248e+09  255.30560  0.401781
# 1           1.634248e+09  255.78620  0.401781
# 2           1.634248e+09  255.48770  0.401781
# 3           1.634248e+09  255.48770  0.401781
# 4           1.634248e+09  255.89550  0.401781
# ...                  ...        ...       ...
# 14398       1.634249e+09   59.91599  0.689762
# 14399       1.634249e+09   60.07620  0.689762
# 14400       1.634249e+09   60.24368  0.698022
# 14401       1.634249e+09   59.92327  0.698899
# 14402       1.634249e+09   60.14173  0.698899
#
# [14403 rows x 3 columns]

# %%
pd_wind.iloc[3,0]-pd_wind.iloc[2,0]
# Out:
# 2.86102294921875e-05

# %%
719/60.
# Out:
# 11.983333333333333

# %%
.12*60
# Out:
# 7.199999999999999

# %%
60/.12
# Out:
# 500.0

# %%
1/.12
# Out:
# 8.333333333333334

# %%
14402/719
# Out:
# 20.030598052851182

# %%
time_array=np.array(pd_wind.iloc[:,0])
wind_array=np.array(pd_wind.iloc[:,1])
spd_array=np.array(pd_wind.iloc[:,2])

# %%
plt.plot((time_array-time_array[0])/60, wind_array)

# %%
plt.plot((time_array-time_array[0])/60, spd_array)

# %%
type(time)
# Out:
# pandas.core.series.Series

# %%
np.array(time)
# Out:
# array([1.63424802e+09, 1.63424802e+09, 1.63424802e+09, ...,
#        1.63424874e+09, 1.63424874e+09, 1.63424874e+09])

# %%
list(time)
# Out:
# [1634248021.0085876,
#  1634248021.136052,
#  1634248021.1361277,
#  1634248021.1361563,
#  1634248021.1361797,
#  1634248021.1362014,
#  1634248021.136222,
#  1634248021.1362412,
#  1634248021.1362607,
#  1634248021.13628,
#  1634248021.136299,
#  1634248021.136318,
#  1634248021.1363378,
#  1634248021.1363573,
#  1634248021.1363769,
#  1634248021.1363957,
#  1634248021.1364162,
#  1634248021.1364355,
#  1634248021.136454,
#  1634248021.1364715,
#  1634248021.136489,
#  1634248021.1365075,
#  1634248021.136526,
#  1634248021.2463412,
#  1634248021.2464314,
#  1634248021.3431444,
#  1634248021.3432608,
#  1634248021.4401944,
#  1634248021.440272,
#  1634248021.552065,
#  1634248021.552147,
#  1634248021.6461124,
#  1634248021.6461885,
#  1634248021.7550924,
#  1634248021.7551985,
#  1634248021.8876393,
#  1634248021.887862,
#  1634248021.8879015,
#  1634248021.9939787,
#  1634248021.994065,
#  1634248022.097991,
#  1634248022.0980654,
#  1634248022.1969492,
#  1634248022.1970203,
# ...
